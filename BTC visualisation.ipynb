# %%
import quandl
import pandas as pd
mydata = quandl.get("BITFINEX/BTCUSD",start_date="01/01/2019")

# %%
print(mydata)
# Out:
#                    High          Low      Mid         Last     Bid     Ask  \
# Date
# 2019-01-01  3987.000000  3788.100000  3957.75  3956.900000  3957.7  3957.8
# 2019-01-02  4083.470676  3917.900000  4061.15  4061.000000  4061.1  4061.2
# 2019-01-04  3986.000000  3850.100000  3959.75  3959.800000  3959.7  3959.8
# 2019-01-05  4014.900000  3901.000000  3910.95  3910.900000  3910.9  3911.0
# 2019-01-06  4218.000000  3887.500000  4172.95  4173.000000  4172.9  4173.0
# 2019-01-07  4197.000000  4044.900000  4112.15  4112.100000  4112.1  4112.2
# 2019-01-09  4168.900000  4010.000000  4083.85  4083.900000  4083.8  4083.9
# 2019-01-11  3777.800000  3666.600000  3710.05  3710.100000  3710.0  3710.1
# 2019-01-12  3734.000000  3666.600000  3701.45  3701.400000  3701.4  3701.5
# 2019-01-13  3729.000000  3570.000000  3581.55  3580.000000  3581.3  3581.8
# 2019-01-14  3799.400000  3580.000000  3749.05  3749.900000  3749.0  3749.1
# ...

# %%
import matplotlib.pyplot as plt

plt.style.use("dark_background")
plt.figure(figsize=(20,7))
plt.grid(linewidth=0.2)
plt.title("BTC(USD) Value")
plt.plot(mydata.index, mydata.Last)
